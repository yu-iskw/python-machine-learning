# %%
from __future__ import absolute_import
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_digits as load_data
import scikitplot as skplt

# %%
X, y = load_data(return_X_y=True)
nb = GaussianNB()
nb.fit(X, y)
# Out:
# GaussianNB(priors=None)

# %%
probas = nb.predict_proba(X)

# %%
skplt.metrics.plot_precision_recall(y_true=y, y_probas=probas, figsize=(8, 6))
plt.show()

# %%
skplt.metrics.plot_roc_curve(y_true=y, y_probas=probas, figsize=(8, 6))
# Out:
# /usr/local/anaconda3/envs/python-machine-learning/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=DeprecationWarning)
